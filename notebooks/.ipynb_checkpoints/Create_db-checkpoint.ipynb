# %% [markdown]
# План ориг. ноутбука
#
# 2. Загрузка модели
#
# 3. Класс langchain эмбеддер, можно попробовать без него, если проверить модель [ссылка](https://huggingface.co/cointegrated/LaBSE-en-ru)
#
# 4. Определение препроцессинга (заменить snowball-stemer)
#
# 5. BM25_retriever + vector_retriever
#
# 6. Загрузка кросс-энкодера (reranker)
#
# 7. final_retriever

# %%
# !git clone https://github.com/profcomff/chatbot-mark-api.git

# %% [markdown]
# # Библиотеки
#
# можно заменить на клонирование из репозитория и установки  requirements.txt?

# %%
# !pip install langchain transformers sentence-transformers -q
# !pip install mistralai -q
# !pip install unstructured -q
# !pip install -U langchain-community -q
# !pip install "unstructured[docx]" -q
# !pip install -qU "langchain-chroma>=0.1.2" -q
# !pip install langchain_huggingface -q
# !pip install rank_bm25 -q
# !pip install natasha -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 26.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 29.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 60.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 25.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 1.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 96.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 86.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 70.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 558.0 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 19.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.2/71.2 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 37.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 104.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.1/453.1 kB 34.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.2 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done

# %%
# Core Python libraries
import re
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
import pickle

from langchain_core.embeddings import Embeddings
from transformers import XLMRobertaTokenizer, XLMRobertaModel
import torch

# Torch and Transformers
import torch
import torch.nn.functional as F
from torch import Tensor
from transformers import (
    AutoModelForSequenceClassification,
    AutoModel,
    AutoTokenizer,
    XLMRobertaTokenizer,
    XLMRobertaModel,
)

# NLTK for text preprocessing
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import SnowballStemmer
import nltk
nltk.download('punkt_tab')

# Sentence Transformers
from sentence_transformers import CrossEncoder

# LangChain - documents and embeddings
from langchain_core.documents import Document
from langchain_core.embeddings import Embeddings
from langchain_core.vectorstores import InMemoryVectorStore


# LangChain - loading, splitting, and vector stores
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_chroma import Chroma

from langchain.embeddings import HuggingFaceEmbeddings #this?
from langchain_huggingface import HuggingFaceEmbeddings #or this?

# LangChain - retrieval and reranking
from langchain.retrievers import (
    ContextualCompressionRetriever,
    EnsembleRetriever
)
from langchain.retrievers.document_compressors import CrossEncoderReranker
from langchain_community.cross_encoders import HuggingFaceCrossEncoder
from langchain_community.retrievers import BM25Retriever
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %% [markdown]
# # Функции/классы

# %%
def safe_add_documents(vector_store, chunks, chroma_batch_size=1000):
    with tqdm(total=len(chunks), desc="Добавление в Chroma", unit="doc") as pbar:
        for i in range(0, len(chunks), chroma_batch_size):
            try:
                batch = chunks[i:i+chroma_batch_size]
                vector_store.add_documents(batch)
                pbar.update(len(batch))
            except Exception as e:
                if "Batch size" in str(e) and "greater than max" in str(e):
                    new_size = chroma_batch_size // 2
                    print(f"Ошибка: {e}. Уменьшаю размер батча до {new_size}")
                    return safe_add_documents(vector_store, chunks[i:], new_size)
                raise
            finally:
                if torch.cuda.is_available():
                    torch.cuda.empty_cache()
    print("Все документы успешно добавлены!")


class E5LangChainEmbedder(Embeddings):
    def __init__(self, tokenizer, model, device='cpu', embed_batch_size=8, chroma_batch_size=1000):
        self.tokenizer = tokenizer
        self.model = model.to(device)
        self.device = device
        self.embed_batch_size = embed_batch_size
        self.chroma_batch_size = chroma_batch_size
        self.model.eval()

    def _average_pool(self, last_hidden_states: Tensor, attention_mask: Tensor) -> Tensor:
        last_hidden = last_hidden_states.masked_fill(~attention_mask[..., None].bool(), 0.0)
        return last_hidden.sum(dim=1) / attention_mask.sum(dim=1)[..., None]

    def embed_documents(self, texts):
        all_embeddings = []
        for i in tqdm(range(0, len(texts), self.embed_batch_size),
                     desc="Вычисление эмбеддингов", unit="batch"):
            batch_texts = texts[i:i+self.embed_batch_size]
            batch_dict = self.tokenizer(
                batch_texts,
                max_length=512,
                padding=True,
                truncation=True,
                return_tensors='pt'
            ).to(self.device)

            with torch.no_grad():
                outputs = self.model(**batch_dict)
                embeddings = self._average_pool(
                    outputs.last_hidden_state,
                    batch_dict['attention_mask']
                )
                embeddings = torch.nn.functional.normalize(embeddings, p=2, dim=1)
                all_embeddings.extend(embeddings.cpu().tolist())

        return all_embeddings

    def embed_query(self, text):
        return self.embed_documents([text])[0]

def preprocess(text):
    stemmer = SnowballStemmer("russian")
    text = re.sub(r'[^а-яё\s]', '', text.lower())

    words = word_tokenize(text, language="russian")

    stemmed_words = [stemmer.stem(word) for word in words if word.strip()]

    return stemmed_words

# %% [markdown]
# # 0. Загрузка таблиц

# %%
answers = pd.read_excel('/content/database_v2.xlsx')

display(answers.answer[0]) #debug
display(answers.head(2))
print(answers.columns)
# Out:
# 'Карта зачет. https://vk.com/wall-24234717_22977\nЭто ваш профсоюзный билет. С помощью этой карты вы можете получать скидки у полезных для студентов популярных брендов, участвовать в конкурсах и розыгрышах, а также посещать концерты и мероприятия. \nПолный перечень скидок есть в статье: vk.cc/bYSCNw.'
#    Unnamed: 0               topic_name  \
# 0           0              Карта зачет
# 1           1  Как вступить в профсоюз
#
#                                               answer  id
# 0  Карта зачет. https://vk.com/wall-24234717_2297...   0
# 1  Как вступить в профсоюз? Чтобы вступить в Проф...   1
# Index(['Unnamed: 0', 'topic_name', 'answer', 'id'], dtype='object')

# %% [markdown]
# # 1. Создание БД

# %%
from langchain.schema import Document

all_chunks = []

for answer, topic_name in zip(answers['answer'], answers['topic_name']):
    all_chunks.append(Document(
        page_content=answer,
        metadata={
            "source": topic_name
        }
    ))

# %%
tokenizer = AutoTokenizer.from_pretrained("d0rj/e5-base-en-ru")
search_model = XLMRobertaModel.from_pretrained('d0rj/e5-base-en-ru', use_cache=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/471 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/279 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/702 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/529M [00:00<?, ?B/s]

# %%
embedder = E5LangChainEmbedder(
    tokenizer=tokenizer,
    model=search_model,
    device='cuda' if torch.cuda.is_available() else 'cpu',
    embed_batch_size=4,
    chroma_batch_size=500
)

vector_store = Chroma(
    collection_name="docs",
    embedding_function=embedder,
    persist_directory="./chroma_db"
)
safe_add_documents(vector_store, all_chunks)
# Out:
# Добавление в Chroma:   0%|          | 0/105 [00:00<?, ?doc/s]
# Вычисление эмбеддингов:   0%|          | 0/27 [00:00<?, ?batch/s]
# Все документы успешно добавлены!

# %%
vector_store = Chroma(
    collection_name="docs",
    embedding_function=embedder,
    persist_directory="./chroma_db"
)

# %% [markdown]
# ## Retriever

# %%
k = 10

bm25_retriever = BM25Retriever.from_documents(
    all_chunks,
    preprocess_func=preprocess
)
bm25_retriever.k = k

vector_retriever = vector_store.as_retriever(search_kwargs={"k": k})

ensemble_retriever = EnsembleRetriever(
    retrievers=[bm25_retriever, vector_retriever],
    weights=[0.35, 0.65]
)

# %%
pickle.dump(bm25_retriever, open('retriever', 'wb'))

# %%
# !zip -r bd_chroma.zip retriever chroma_db/
# Out:
#   adding: retriever (deflated 77%)
#   adding: chroma_db/ (stored 0%)
#   adding: chroma_db/chroma.sqlite3 (deflated 52%)
#   adding: chroma_db/b9ccfd15-7a04-4132-8e1d-6fd6163cc3c1/ (stored 0%)
#   adding: chroma_db/b9ccfd15-7a04-4132-8e1d-6fd6163cc3c1/data_level0.bin (deflated 100%)
#   adding: chroma_db/b9ccfd15-7a04-4132-8e1d-6fd6163cc3c1/link_lists.bin (stored 0%)
#   adding: chroma_db/b9ccfd15-7a04-4132-8e1d-6fd6163cc3c1/header.bin (deflated 61%)
#   adding: chroma_db/b9ccfd15-7a04-4132-8e1d-6fd6163cc3c1/length.bin (deflated 100%)

# %%
preprocess('Как дела?')
# Out:
# ['как', 'дел']

# %%
ensemble_retriever = EnsembleRetriever(
    retrievers=[bm25_retriever, vector_retriever],
    weights=[0.35, 0.65],
)

# %%
query = "Как поступить на МФК?"
results = ensemble_retriever.get_relevant_documents(query)
# Out:
# Вычисление эмбеддингов:   0%|          | 0/1 [00:00<?, ?batch/s]

# %%
results[:3]
# Out:
# [Document(metadata={'source': 'Запись на МФК'}, page_content='Запись на МФК. Как записаться на МФК? Запись на МФК осуществляется через портал lk.msu.ru.'),
#  Document(metadata={'source': 'МФК'}, page_content='МФК — это межфакультетские курсы, обязательные для всех студентов МГУ. Они направлены на расширение знаний студента в сферах, не связанных со специализацией. Проходить МФК можно на любом факультете, но в зачет не идут МФК, проводимые на факультете, где учится студент.\n\nДля студентов, обучающихся по специальности «Фундаментальная и прикладная физика» МФК являются обязательными по учебному плану в 7–10 семестрах, по специальности «Астрономия» в 5–8 семестрах. Курсы, пройденные в семестрах ранее, могут быть перезачтены.\n\n▪ Как минимум один прослушанный курс должен быть по тематике искусственного интеллекта.\n▪️ Запись на МФК осуществляется через портал lk.msu.ru.'),
#  Document(metadata={'source': 'Определение МФК'}, page_content='Определение МФК. Что такое МФК? МФК — это межфакультетские курсы, обязательные для всех студентов МГУ. Они направлены на расширение знаний студента в сферах, не связанных со специализацией. Проходить МФК можно на любом факультете, но в зачет не идут МФК, проводимые на факультете, где учится студент.')]
